# %% [markdown]
# # Daily News Stock Market Prediction
#
# ---
#
# **Table of Contents**
#
# [1.0 Objectives](#1.0-Objectives)
# [2.0 Import Library](#2.0-Import-Library)
# [3.0 Set Constant and Default Settings](#3.0-Set-Constant-and-Default-Settings)
# [4.0 Load Dataset](#4.0-Load-Dataset)
#
# ---

# %% [markdown]
# # 1.0 Objectives
#
# - To predict the stock market movement with daily news

# %% [markdown]
# # 2.0 Import Library

# %%
# System
import os

# EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Deep learning
import tensorflow as tf

# Preprocessing
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_extraction.text import CountVectorizer

# Metrics
from sklearn.metrics import roc_auc_score, plot_roc_curve
from tensorflow.keras.metrics import AUC

# Model
from sklearn.linear_model import LogisticRegression
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense

# Optimisation
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # 3.0 Set Constant and Default Settings

# %%
plt.rcParams['figure.dpi'] = 150
sns.set_style('dark')

# %%
base_dir = os.path.join('/', 'kaggle', 'input', 'stocknews')

# Check is kaggle env or local env
is_kaggle = os.path.exists(base_dir)

dataset_path = os.path.join(base_dir if is_kaggle else '', 'Combined_News_DJIA.csv')

# %% [markdown]
# # 4.0 Load Dataset

# %%
df = pd.read_csv(dataset_path, parse_dates=['Date'], index_col='Date')

# %% [markdown]
# As feature *date* is used as index, we will sort the dataset in chronological order

# %%
df = df.sort_index()

# %% [markdown]
# # 5.0 Overview of Dataset

# %%
df.head()
# Out:
#             Label                                               Top1  \
# Date
# 2008-08-08      0  b"Georgia 'downs two Russian warplanes' as cou...
# 2008-08-11      1  b'Why wont America and Nato help us? If they w...
# 2008-08-12      0  b'Remember that adorable 9-year-old who sang a...
# 2008-08-13      0  b' U.S. refuses Israel weapons to attack Iran:...
# 2008-08-14      1  b'All the experts admit that we should legalis...
#
#                                                          Top2  \
# Date
# 2008-08-08            b'BREAKING: Musharraf to be impeached.'
# 2008-08-11        b'Bush puts foot down on Georgian conflict'
# 2008-08-12                 b"Russia 'ends Georgia operation'"
# 2008-08-13  b"When the president ordered to attack Tskhinv...
# 2008-08-14  b'War in South Osetia - 89 pictures made by a ...
#
#                                                          Top3  \
# Date
# 2008-08-08  b'Russia Today: Columns of troops roll into So...
# 2008-08-11  b"Jewish Georgian minister: Thanks to Israeli ...
# 2008-08-12  b'"If we had no sexual harassment we would hav...
# 2008-08-13  b' Israel clears troops who killed Reuters cam...
# 2008-08-14  b'Swedish wrestler Ara Abrahamian throws away ...
#
#                                                          Top4  \
# Date
# 2008-08-08  b'Russian tanks are moving towards the capital...
# 2008-08-11  b'Georgian army flees in disarray as Russians ...
# 2008-08-12  b"Al-Qa'eda is losing support in Iraq because ...
# 2008-08-13  b'Britain\'s policy of being tough on drugs is...
# 2008-08-14  b'Russia exaggerated the death toll in South O...
#
#                                                          Top5  \
# Date
# 2008-08-08  b"Afghan children raped with 'impunity,' U.N. ...
# 2008-08-11      b"Olympic opening ceremony fireworks 'faked'"
# 2008-08-12  b'Ceasefire in Georgia: Putin Outmaneuvers the...
# 2008-08-13  b'Body of 14 year old found in trunk; Latest (...
# 2008-08-14  b'Missile That Killed 9 Inside Pakistan May Ha...
#
#                                                          Top6  \
# Date
# 2008-08-08  b'150 Russian tanks have entered South Ossetia...
# 2008-08-11  b'What were the Mossad with fraudulent New Zea...
# 2008-08-12  b'Why Microsoft and Intel tried to kill the XO...
# 2008-08-13  b'China has moved 10 *million* quake survivors...
# 2008-08-14  b"Rushdie Condemns Random House's Refusal to P...
#
#                                                          Top7  \
# Date
# 2008-08-08  b"Breaking: Georgia invades South Ossetia, Rus...
# 2008-08-11  b'Russia angered by Israeli military sale to G...
# 2008-08-12  b'Stratfor: The Russo-Georgian War and the Bal...
# 2008-08-13  b"Bush announces Operation Get All Up In Russi...
# 2008-08-14  b'Poland and US agree to missle defense deal. ...
#
#                                                          Top8  \
# Date
# 2008-08-08  b"The 'enemy combatent' trials are nothing but...
# 2008-08-11  b'An American citizen living in S.Ossetia blam...
# 2008-08-12  b"I'm Trying to Get a Sense of This Whole Geor...
# 2008-08-13             b'Russian forces sink Georgian ships '
# 2008-08-14  b'Will the Russians conquer Tblisi? Bet on it,...
#
#                                                          Top9  ...  \
# Date                                                           ...
# 2008-08-08  b'Georgian troops retreat from S. Osettain cap...  ...
# 2008-08-11  b'Welcome To World War IV! Now In High Definit...  ...
# 2008-08-12  b"The US military was surprised by the timing ...  ...
# 2008-08-13  b"The commander of a Navy air reconnaissance s...  ...
# 2008-08-14  b'Russia exaggerating South Ossetian death tol...  ...
#
#                                                         Top16  \
# Date
# 2008-08-08  b'Georgia Invades South Ossetia - if Russia ge...
# 2008-08-11  b'Israel and the US behind the Georgian aggres...
# 2008-08-12  b'U.S. troops still in Georgia (did you know t...
# 2008-08-13                      b'Elephants extinct by 2020?'
# 2008-08-14  b'Bank analyst forecast Georgian crisis 2 days...
#
#                                                         Top17  \
# Date
# 2008-08-08                b'Al-Qaeda Faces Islamist Backlash'
# 2008-08-11  b'"Do not believe TV, neither Russian nor Geor...
# 2008-08-12       b'Why Russias response to Georgia was right'
# 2008-08-13  b'US humanitarian missions soon in Georgia - i...
# 2008-08-14  b"Georgia confict could set back Russia's US r...
#
#                                                         Top18  \
# Date
# 2008-08-08  b'Condoleezza Rice: "The US would not act to p...
# 2008-08-11  b'Riots are still going on in Montreal (Canada...
# 2008-08-12  b'Gorbachev accuses U.S. of making a "serious ...
# 2008-08-13             b"Georgia's DDOS came from US sources"
# 2008-08-14  b'War in the Caucasus is as much the product o...
#
#                                                         Top19  \
# Date
# 2008-08-08  b'This is a busy day:  The European Union has ...
# 2008-08-11    b'China to overtake US as largest manufacturer'
# 2008-08-12         b'Russia, Georgia, and NATO: Cold War Two'
# 2008-08-13  b'Russian convoy heads into Georgia, violating...
# 2008-08-14  b'"Non-media" photos of South Ossetia/Georgia ...
#
#                                                         Top20  \
# Date
# 2008-08-08  b"Georgia will withdraw 1,000 soldiers from Ir...
# 2008-08-11                     b'War in South Ossetia [PICS]'
# 2008-08-12  b'Remember that adorable 62-year-old who led y...
# 2008-08-13  b'Israeli defence minister: US against strike ...
# 2008-08-14  b'Georgian TV reporter shot by Russian sniper ...
#
#                                                         Top21  \
# Date
# 2008-08-08  b'Why the Pentagon Thinks Attacking Iran is a ...
# 2008-08-11  b'Israeli Physicians Group Condemns State Tort...
# 2008-08-12          b'War in Georgia: The Israeli connection'
# 2008-08-13                     b'Gorbachev: We Had No Choice'
# 2008-08-14  b'Saudi Arabia: Mother moves to block child ma...
#
#                                                         Top22  \
# Date
# 2008-08-08  b'Caucasus in crisis: Georgia invades South Os...
# 2008-08-11  b' Russia has just beaten the United States ov...
# 2008-08-12  b'All signs point to the US encouraging Georgi...
# 2008-08-13  b'Witness: Russian forces head towards Tbilisi...
# 2008-08-14   b'Taliban wages war on humanitarian aid workers'
#
#                                                         Top23  \
# Date
# 2008-08-08  b'Indian shoe manufactory  - And again in a se...
# 2008-08-11  b'Perhaps *the* question about the Georgia - R...
# 2008-08-12  b'Christopher King argues that the US and NATO...
# 2008-08-13  b' Quarter of Russians blame U.S. for conflict...
# 2008-08-14  b'Russia: World  "can forget about" Georgia\'s...
#
#                                                         Top24  \
# Date
# 2008-08-08  b'Visitors Suffering from Mental Illnesses Ban...
# 2008-08-11                 b'Russia is so much better at war'
# 2008-08-12                        b'America: The New Mexico?'
# 2008-08-13  b'Georgian president  says US military will ta...
# 2008-08-14  b'Darfur rebels accuse Sudan of mounting major...
#
#                                                         Top25
# Date
# 2008-08-08           b"No Help for Mexico's Kidnapping Surge"
# 2008-08-11  b"So this is what it's come to: trading sex fo...
# 2008-08-12  b"BBC NEWS | Asia-Pacific | Extinction 'by man...
# 2008-08-13  b'2006: Nobel laureate Aleksander Solzhenitsyn...
# 2008-08-14  b'Philippines : Peace Advocate say Muslims nee...
#
# [5 rows x 26 columns]

# %% [markdown]
# # 6.0 Split dataset into train and test set

# %% [markdown]
# Since the dataset is a time series, the trivial approach to split the dataset into train and test set randomly is not applicable in time series. The time orderly of the dataset is important as the real life event are happened in chronological order.
#
# 20% of the dataset will be reserved for test set.

# %%
dataset_size = len(df)

train_size_index = int(dataset_size * 0.8)

# %%
train_df = df[:train_size_index]
test_df = df[train_size_index:]

# %% [markdown]
# # 7.0 Exploratory Data Analysis (EDA)

# %% [markdown]
# ## 7.1 Statistics Summary of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1989 entries, 2008-08-08 to 2016-07-01
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Label   1989 non-null   int64
#  1   Top1    1989 non-null   object
#  2   Top2    1989 non-null   object
#  3   Top3    1989 non-null   object
#  4   Top4    1989 non-null   object
#  5   Top5    1989 non-null   object
#  6   Top6    1989 non-null   object
#  7   Top7    1989 non-null   object
#  8   Top8    1989 non-null   object
#  9   Top9    1989 non-null   object
#  10  Top10   1989 non-null   object
#  11  Top11   1989 non-null   object
#  12  Top12   1989 non-null   object
#  13  Top13   1989 non-null   object
#  14  Top14   1989 non-null   object
#  15  Top15   1989 non-null   object
#  16  Top16   1989 non-null   object
#  17  Top17   1989 non-null   object
#  18  Top18   1989 non-null   object
#  19  Top19   1989 non-null   object
#  20  Top20   1989 non-null   object
#  21  Top21   1989 non-null   object
#  22  Top22   1989 non-null   object
#  23  Top23   1988 non-null   object
#  24  Top24   1986 non-null   object
#  25  Top25   1986 non-null   object
# dtypes: int64(1), object(25)
# memory usage: 419.6+ KB

# %%
df.columns
# Out:
# Index(['Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5', 'Top6', 'Top7', 'Top8',
#        'Top9', 'Top10', 'Top11', 'Top12', 'Top13', 'Top14', 'Top15', 'Top16',
#        'Top17', 'Top18', 'Top19', 'Top20', 'Top21', 'Top22', 'Top23', 'Top24',
#        'Top25'],
#       dtype='object')

# %%
label_weight_perc = train_df['Label'].value_counts(normalize=True) * 100

label_weight_perc
# Out:
# 1    54.242615
# 0    45.757385
# Name: Label, dtype: float64

# %% [markdown]
# The feature *label* will be the target for training the model. The ratio between 0 and 1 is fairly balanced.

# %% [markdown]
# ## 7.2 Data Cleaning

# %%
train_df.isnull().sum()
# Out:
# Label    0
# Top1     0
# Top2     0
# Top3     0
# Top4     0
# Top5     0
# Top6     0
# Top7     0
# Top8     0
# Top9     0
# Top10    0
# Top11    0
# Top12    0
# Top13    0
# Top14    0
# Top15    0
# Top16    0
# Top17    0
# Top18    0
# Top19    0
# Top20    0
# Top21    0
# Top22    0
# Top23    1
# Top24    3
# Top25    3
# dtype: int64

# %% [markdown]
# Feature *Top23*, *Top24*, *Top25* contain missing values. However, it isn't necessary to deal with these instances as some day will not have so many hot news. We can fill in the missing value as empty string.

# %%
train_df = train_df.fillna('')

# %%
train_df.head()
# Out:
#             Label                                               Top1  \
# Date
# 2008-08-08      0  b"Georgia 'downs two Russian warplanes' as cou...
# 2008-08-11      1  b'Why wont America and Nato help us? If they w...
# 2008-08-12      0  b'Remember that adorable 9-year-old who sang a...
# 2008-08-13      0  b' U.S. refuses Israel weapons to attack Iran:...
# 2008-08-14      1  b'All the experts admit that we should legalis...
#
#                                                          Top2  \
# Date
# 2008-08-08            b'BREAKING: Musharraf to be impeached.'
# 2008-08-11        b'Bush puts foot down on Georgian conflict'
# 2008-08-12                 b"Russia 'ends Georgia operation'"
# 2008-08-13  b"When the president ordered to attack Tskhinv...
# 2008-08-14  b'War in South Osetia - 89 pictures made by a ...
#
#                                                          Top3  \
# Date
# 2008-08-08  b'Russia Today: Columns of troops roll into So...
# 2008-08-11  b"Jewish Georgian minister: Thanks to Israeli ...
# 2008-08-12  b'"If we had no sexual harassment we would hav...
# 2008-08-13  b' Israel clears troops who killed Reuters cam...
# 2008-08-14  b'Swedish wrestler Ara Abrahamian throws away ...
#
#                                                          Top4  \
# Date
# 2008-08-08  b'Russian tanks are moving towards the capital...
# 2008-08-11  b'Georgian army flees in disarray as Russians ...
# 2008-08-12  b"Al-Qa'eda is losing support in Iraq because ...
# 2008-08-13  b'Britain\'s policy of being tough on drugs is...
# 2008-08-14  b'Russia exaggerated the death toll in South O...
#
#                                                          Top5  \
# Date
# 2008-08-08  b"Afghan children raped with 'impunity,' U.N. ...
# 2008-08-11      b"Olympic opening ceremony fireworks 'faked'"
# 2008-08-12  b'Ceasefire in Georgia: Putin Outmaneuvers the...
# 2008-08-13  b'Body of 14 year old found in trunk; Latest (...
# 2008-08-14  b'Missile That Killed 9 Inside Pakistan May Ha...
#
#                                                          Top6  \
# Date
# 2008-08-08  b'150 Russian tanks have entered South Ossetia...
# 2008-08-11  b'What were the Mossad with fraudulent New Zea...
# 2008-08-12  b'Why Microsoft and Intel tried to kill the XO...
# 2008-08-13  b'China has moved 10 *million* quake survivors...
# 2008-08-14  b"Rushdie Condemns Random House's Refusal to P...
#
#                                                          Top7  \
# Date
# 2008-08-08  b"Breaking: Georgia invades South Ossetia, Rus...
# 2008-08-11  b'Russia angered by Israeli military sale to G...
# 2008-08-12  b'Stratfor: The Russo-Georgian War and the Bal...
# 2008-08-13  b"Bush announces Operation Get All Up In Russi...
# 2008-08-14  b'Poland and US agree to missle defense deal. ...
#
#                                                          Top8  \
# Date
# 2008-08-08  b"The 'enemy combatent' trials are nothing but...
# 2008-08-11  b'An American citizen living in S.Ossetia blam...
# 2008-08-12  b"I'm Trying to Get a Sense of This Whole Geor...
# 2008-08-13             b'Russian forces sink Georgian ships '
# 2008-08-14  b'Will the Russians conquer Tblisi? Bet on it,...
#
#                                                          Top9  ...  \
# Date                                                           ...
# 2008-08-08  b'Georgian troops retreat from S. Osettain cap...  ...
# 2008-08-11  b'Welcome To World War IV! Now In High Definit...  ...
# 2008-08-12  b"The US military was surprised by the timing ...  ...
# 2008-08-13  b"The commander of a Navy air reconnaissance s...  ...
# 2008-08-14  b'Russia exaggerating South Ossetian death tol...  ...
#
#                                                         Top16  \
# Date
# 2008-08-08  b'Georgia Invades South Ossetia - if Russia ge...
# 2008-08-11  b'Israel and the US behind the Georgian aggres...
# 2008-08-12  b'U.S. troops still in Georgia (did you know t...
# 2008-08-13                      b'Elephants extinct by 2020?'
# 2008-08-14  b'Bank analyst forecast Georgian crisis 2 days...
#
#                                                         Top17  \
# Date
# 2008-08-08                b'Al-Qaeda Faces Islamist Backlash'
# 2008-08-11  b'"Do not believe TV, neither Russian nor Geor...
# 2008-08-12       b'Why Russias response to Georgia was right'
# 2008-08-13  b'US humanitarian missions soon in Georgia - i...
# 2008-08-14  b"Georgia confict could set back Russia's US r...
#
#                                                         Top18  \
# Date
# 2008-08-08  b'Condoleezza Rice: "The US would not act to p...
# 2008-08-11  b'Riots are still going on in Montreal (Canada...
# 2008-08-12  b'Gorbachev accuses U.S. of making a "serious ...
# 2008-08-13             b"Georgia's DDOS came from US sources"
# 2008-08-14  b'War in the Caucasus is as much the product o...
#
#                                                         Top19  \
# Date
# 2008-08-08  b'This is a busy day:  The European Union has ...
# 2008-08-11    b'China to overtake US as largest manufacturer'
# 2008-08-12         b'Russia, Georgia, and NATO: Cold War Two'
# 2008-08-13  b'Russian convoy heads into Georgia, violating...
# 2008-08-14  b'"Non-media" photos of South Ossetia/Georgia ...
#
#                                                         Top20  \
# Date
# 2008-08-08  b"Georgia will withdraw 1,000 soldiers from Ir...
# 2008-08-11                     b'War in South Ossetia [PICS]'
# 2008-08-12  b'Remember that adorable 62-year-old who led y...
# 2008-08-13  b'Israeli defence minister: US against strike ...
# 2008-08-14  b'Georgian TV reporter shot by Russian sniper ...
#
#                                                         Top21  \
# Date
# 2008-08-08  b'Why the Pentagon Thinks Attacking Iran is a ...
# 2008-08-11  b'Israeli Physicians Group Condemns State Tort...
# 2008-08-12          b'War in Georgia: The Israeli connection'
# 2008-08-13                     b'Gorbachev: We Had No Choice'
# 2008-08-14  b'Saudi Arabia: Mother moves to block child ma...
#
#                                                         Top22  \
# Date
# 2008-08-08  b'Caucasus in crisis: Georgia invades South Os...
# 2008-08-11  b' Russia has just beaten the United States ov...
# 2008-08-12  b'All signs point to the US encouraging Georgi...
# 2008-08-13  b'Witness: Russian forces head towards Tbilisi...
# 2008-08-14   b'Taliban wages war on humanitarian aid workers'
#
#                                                         Top23  \
# Date
# 2008-08-08  b'Indian shoe manufactory  - And again in a se...
# 2008-08-11  b'Perhaps *the* question about the Georgia - R...
# 2008-08-12  b'Christopher King argues that the US and NATO...
# 2008-08-13  b' Quarter of Russians blame U.S. for conflict...
# 2008-08-14  b'Russia: World  "can forget about" Georgia\'s...
#
#                                                         Top24  \
# Date
# 2008-08-08  b'Visitors Suffering from Mental Illnesses Ban...
# 2008-08-11                 b'Russia is so much better at war'
# 2008-08-12                        b'America: The New Mexico?'
# 2008-08-13  b'Georgian president  says US military will ta...
# 2008-08-14  b'Darfur rebels accuse Sudan of mounting major...
#
#                                                         Top25
# Date
# 2008-08-08           b"No Help for Mexico's Kidnapping Surge"
# 2008-08-11  b"So this is what it's come to: trading sex fo...
# 2008-08-12  b"BBC NEWS | Asia-Pacific | Extinction 'by man...
# 2008-08-13  b'2006: Nobel laureate Aleksander Solzhenitsyn...
# 2008-08-14  b'Philippines : Peace Advocate say Muslims nee...
#
# [5 rows x 26 columns]

# %% [markdown]
# # 8.0 Preprocessing

# %% [markdown]
# ## 8.1 Data Cleaning

# %%
type(train_df['Top1'][0])
# Out:
# str

# %% [markdown]
# At first glance, the string start with "b'...'" and intuitively the data type is byte-sequence. However, it isn't the case. Just by executing the `type()` function, we can know that the string data type is already in string. Thus, we need to do data cleaning on the data by removing the byte-sequence format that been encoded into the string.

# %%
def clean_byte_str(df: pd.DataFrame, cols: list):
    strip_ch = "b\'\""

    return df[cols].apply(lambda x: x.str.strip(strip_ch), axis=1)

# %%
txt_cols = [f'Top{x}' for x in range(1, 26)]

# %%
preprocessed_txt_df = clean_byte_str(train_df, txt_cols)

train_df = train_df.drop(txt_cols, axis=1).merge(preprocessed_txt_df, how='outer', left_index=True, right_index=True)

# %% [markdown]
# ## 8.2 Aggregate Texts Feature Column

# %% [markdown]
# We will be aggregate the column from *Top1* to *Top25* as feature *TopNews*.

# %%
train_df.head()
# Out:
#             Label                                               Top1  \
# Date
# 2008-08-08      0  Georgia 'downs two Russian warplanes' as count...
# 2008-08-11      1  Why wont America and Nato help us? If they won...
# 2008-08-12      0  Remember that adorable 9-year-old who sang at ...
# 2008-08-13      0   U.S. refuses Israel weapons to attack Iran: r...
# 2008-08-14      1  All the experts admit that we should legalise ...
#
#                                                          Top2  \
# Date
# 2008-08-08               BREAKING: Musharraf to be impeached.
# 2008-08-11           Bush puts foot down on Georgian conflict
# 2008-08-12                     Russia 'ends Georgia operation
# 2008-08-13  When the president ordered to attack Tskhinval...
# 2008-08-14  War in South Osetia - 89 pictures made by a Ru...
#
#                                                          Top3  \
# Date
# 2008-08-08  Russia Today: Columns of troops roll into Sout...
# 2008-08-11  Jewish Georgian minister: Thanks to Israeli tr...
# 2008-08-12  If we had no sexual harassment we would have n...
# 2008-08-13   Israel clears troops who killed Reuters camer...
# 2008-08-14  Swedish wrestler Ara Abrahamian throws away me...
#
#                                                          Top4  \
# Date
# 2008-08-08  Russian tanks are moving towards the capital o...
# 2008-08-11  Georgian army flees in disarray as Russians ad...
# 2008-08-12  Al-Qa'eda is losing support in Iraq because of...
# 2008-08-13  Britain\'s policy of being tough on drugs is "...
# 2008-08-14  Russia exaggerated the death toll in South Oss...
#
#                                                          Top5  \
# Date
# 2008-08-08  Afghan children raped with 'impunity,' U.N. of...
# 2008-08-11          Olympic opening ceremony fireworks 'faked
# 2008-08-12  Ceasefire in Georgia: Putin Outmaneuvers the West
# 2008-08-13  Body of 14 year old found in trunk; Latest (ra...
# 2008-08-14  Missile That Killed 9 Inside Pakistan May Have...
#
#                                                          Top6  \
# Date
# 2008-08-08  150 Russian tanks have entered South Ossetia w...
# 2008-08-11  What were the Mossad with fraudulent New Zeala...
# 2008-08-12  Why Microsoft and Intel tried to kill the XO $...
# 2008-08-13  China has moved 10 *million* quake survivors i...
# 2008-08-14  Rushdie Condemns Random House's Refusal to Pub...
#
#                                                          Top7  \
# Date
# 2008-08-08  Breaking: Georgia invades South Ossetia, Russi...
# 2008-08-11  Russia angered by Israeli military sale to Geo...
# 2008-08-12  Stratfor: The Russo-Georgian War and the Balan...
# 2008-08-13  Bush announces Operation Get All Up In Russia'...
# 2008-08-14  Poland and US agree to missle defense deal. In...
#
#                                                          Top8  \
# Date
# 2008-08-08  The 'enemy combatent' trials are nothing but a...
# 2008-08-11  An American citizen living in S.Ossetia blames...
# 2008-08-12  I'm Trying to Get a Sense of This Whole Georgi...
# 2008-08-13                Russian forces sink Georgian ships
# 2008-08-14  Will the Russians conquer Tblisi? Bet on it, n...
#
#                                                          Top9  ...  \
# Date                                                           ...
# 2008-08-08  Georgian troops retreat from S. Osettain capit...  ...
# 2008-08-11   Welcome To World War IV! Now In High Definition!  ...
# 2008-08-12  The US military was surprised by the timing an...  ...
# 2008-08-13  The commander of a Navy air reconnaissance squ...  ...
# 2008-08-14  Russia exaggerating South Ossetian death toll,...  ...
#
#                                                         Top16  \
# Date
# 2008-08-08  Georgia Invades South Ossetia - if Russia gets...
# 2008-08-11  Israel and the US behind the Georgian aggression?
# 2008-08-12  U.S. troops still in Georgia (did you know the...
# 2008-08-13                         Elephants extinct by 2020?
# 2008-08-14  Bank analyst forecast Georgian crisis 2 days e...
#
#                                                         Top17  \
# Date
# 2008-08-08                   Al-Qaeda Faces Islamist Backlash
# 2008-08-11  Do not believe TV, neither Russian nor Georgia...
# 2008-08-12          Why Russias response to Georgia was right
# 2008-08-13  US humanitarian missions soon in Georgia - if ...
# 2008-08-14  Georgia confict could set back Russia's US rel...
#
#                                                         Top18  \
# Date
# 2008-08-08  Condoleezza Rice: "The US would not act to pre...
# 2008-08-11  Riots are still going on in Montreal (Canada) ...
# 2008-08-12  Gorbachev accuses U.S. of making a "serious bl...
# 2008-08-13                Georgia's DDOS came from US sources
# 2008-08-14  War in the Caucasus is as much the product of ...
#
#                                                         Top19  \
# Date
# 2008-08-08  This is a busy day:  The European Union has ap...
# 2008-08-11       China to overtake US as largest manufacturer
# 2008-08-12            Russia, Georgia, and NATO: Cold War Two
# 2008-08-13  Russian convoy heads into Georgia, violating t...
# 2008-08-14  Non-media" photos of South Ossetia/Georgia con...
#
#                                                         Top20  \
# Date
# 2008-08-08  Georgia will withdraw 1,000 soldiers from Iraq...
# 2008-08-11                        War in South Ossetia [PICS]
# 2008-08-12  Remember that adorable 62-year-old who led you...
# 2008-08-13  Israeli defence minister: US against strike on...
# 2008-08-14  Georgian TV reporter shot by Russian sniper du...
#
#                                                         Top21  \
# Date
# 2008-08-08  Why the Pentagon Thinks Attacking Iran is a Ba...
# 2008-08-11    Israeli Physicians Group Condemns State Torture
# 2008-08-12             War in Georgia: The Israeli connection
# 2008-08-13                        Gorbachev: We Had No Choice
# 2008-08-14  Saudi Arabia: Mother moves to block child marr...
#
#                                                         Top22  \
# Date
# 2008-08-08  Caucasus in crisis: Georgia invades South Ossetia
# 2008-08-11   Russia has just beaten the United States over...
# 2008-08-12  All signs point to the US encouraging Georgia ...
# 2008-08-13  Witness: Russian forces head towards Tbilisi i...
# 2008-08-14      Taliban wages war on humanitarian aid workers
#
#                                                         Top23  \
# Date
# 2008-08-08  Indian shoe manufactory  - And again in a seri...
# 2008-08-11  Perhaps *the* question about the Georgia - Rus...
# 2008-08-12  Christopher King argues that the US and NATO a...
# 2008-08-13   Quarter of Russians blame U.S. for conflict: ...
# 2008-08-14  Russia: World  "can forget about" Georgia\'s t...
#
#                                                         Top24  \
# Date
# 2008-08-08  Visitors Suffering from Mental Illnesses Banne...
# 2008-08-11                    Russia is so much better at war
# 2008-08-12                           America: The New Mexico?
# 2008-08-13  Georgian president  says US military will take...
# 2008-08-14  Darfur rebels accuse Sudan of mounting major a...
#
#                                                         Top25
# Date
# 2008-08-08              No Help for Mexico's Kidnapping Surge
# 2008-08-11  So this is what it's come to: trading sex for ...
# 2008-08-12  BBC NEWS | Asia-Pacific | Extinction 'by man n...
# 2008-08-13  2006: Nobel laureate Aleksander Solzhenitsyn a...
# 2008-08-14  Philippines : Peace Advocate say Muslims need ...
#
# [5 rows x 26 columns]

# %%
 train_df['TopNews'] = train_df[txt_cols].apply('; '.join, axis=1)

 train_df = train_df.drop(txt_cols, axis=1)

# %%
train_df.head()
# Out:
#             Label                                            TopNews
# Date
# 2008-08-08      0  Georgia 'downs two Russian warplanes' as count...
# 2008-08-11      1  Why wont America and Nato help us? If they won...
# 2008-08-12      0  Remember that adorable 9-year-old who sang at ...
# 2008-08-13      0   U.S. refuses Israel weapons to attack Iran: r...
# 2008-08-14      1  All the experts admit that we should legalise ...

# %%
train_df.iloc[0]['TopNews']
# Out:
# 'Georgia \'downs two Russian warplanes\' as countries move to brink of war; BREAKING: Musharraf to be impeached.; Russia Today: Columns of troops roll into South Ossetia; footage from fighting (YouTube); Russian tanks are moving towards the capital of South Ossetia, which has reportedly been completely destroyed by Georgian artillery fire; Afghan children raped with \'impunity,\' U.N. official says - this is sick, a three year old was raped and they do nothing; 150 Russian tanks have entered South Ossetia whilst Georgia shoots down two Russian jets.; Breaking: Georgia invades South Ossetia, Russia warned it would intervene on SO\'s side; The \'enemy combatent\' trials are nothing but a sham: Salim Haman has been sentenced to 5 1/2 years, but will be kept longer anyway just because they feel like it.; Georgian troops retreat from S. Osettain capital, presumably leaving several hundred people killed. [VIDEO]; Did the U.S. Prep Georgia for War with Russia?; Rice Gives Green Light for Israel to Attack Iran: Says U.S. has no veto over Israeli military ops; Announcing:Class Action Lawsuit on Behalf of American Public Against the FBI; So---Russia and Georgia are at war and the NYT\'s top story is opening ceremonies of the Olympics?  What a fucking disgrace and yet further proof of the decline of journalism.; China tells Bush to stay out of other countries\' affairs; Did World War III start today?; Georgia Invades South Ossetia - if Russia gets involved, will NATO absorb Georgia and unleash a full scale war?; Al-Qaeda Faces Islamist Backlash; Condoleezza Rice: "The US would not act to prevent an Israeli strike on Iran." Israeli Defense Minister Ehud Barak: "Israel is prepared for uncompromising victory in the case of military hostilities.; This is a busy day:  The European Union has approved new sanctions against Iran in protest at its nuclear programme.; Georgia will withdraw 1,000 soldiers from Iraq to help fight off Russian forces in Georgia\'s breakaway region of South Ossetia; Why the Pentagon Thinks Attacking Iran is a Bad Idea - US News &amp; World Report; Caucasus in crisis: Georgia invades South Ossetia; Indian shoe manufactory  - And again in a series of "you do not like your work?; Visitors Suffering from Mental Illnesses Banned from Olympics; No Help for Mexico\'s Kidnapping Surge'

# %% [markdown]
# # 9.0 Model Evaluation Metrics

# %% [markdown]
# As the dataset target is fairly balanced and it is a binary classification problem. We will be using the **Area Under the Receiver Operating Characteristic Curve (ROC AUC)** score to evalute our model.
#
# We will be also using the `TimeSeriesSplit()` method from *scikit-learn* library to perform cross-validation on the train dataset. It is because the dataset is time sensitive.

# %%
model_eval = {
    'model': [],
    'roc_auc': [],
}

def add_model_eval(model, roc_auc_list: list):
    roc_auc = np.array(roc_auc_list).mean()

    model_eval['model'].append(model)
    model_eval['roc_auc'].append(f'{roc_auc: .2f}')
    
def view_models_eval(sort=False):
    eval_df = pd.DataFrame(model_eval)
    
    if sort:
        eval_df = eval_df.sort_values(by=['roc_auc'], ascending=[False])
    
    display(eval_df.style.hide_index())

# %% [markdown]
# # 10.0 Plan of Model Training

# %% [markdown]
# We will be using *TensorFlow 2.0* library to train the deep learning model. On top of that, we will be applying natural language processing (NLP) technique to the dataset. There are 2 major way on dealing text before feeding into neural network.
#
# - One-Hot Encoding
#   - The words in sentence are represented by columns of matrix
#   - Matrix of one-hot encoding are sparse
#   - Due to the simplicity of the representation, it doesn't work well in the natural language application as matrix is a 2-dimensional tensor
#   - Only capture the word location
# - Word Vector
#   - This is a game changer as word can be represented in n-dimensional
#   - Not only it can capture the word location but the word meaning too

# %% [markdown]
# In total, we will be training 6 different model on the training dataset.
#
# Firstly, we will perform one-hot encoding on the text features. After preprocessing the train dataset, we will use logistic regression to train the model. Logistic regression will act as the benchmark model for later deep learning model. Moving on, we will use Deep Neural Network (DNN) and Long Short-Term Memory (LSTM) to train on the same dataset.
#
# Afterwards, we will preprocess the word in dataset using word vector and use DNN and LSTM to train the preprocessed dataset.
#
# All the training of deep learning model will incorporate early stopping callbacks to let the model to train to its optimum state.
#
# Lastly, we will use the state of the art of natural language processing model for this sentiment analysis task. By taking advantage of pre-trained model that been trained on a huge dataset, we can fine-tune it for our specific task.

# %% [markdown]
# # 11.0 Deep Learning Model

# %% [markdown]
# ## 11.1 One-Hot Encoding

# %% [markdown]
# ### 11.1.1 Benchmark Model - Logistic Regression

# %%
X_train = train_df['TopNews']
y_train = train_df['Label']

# %%
scores = []

tscv = TimeSeriesSplit(n_splits=2)

for train_index, val_index in tscv.split(X_train):
    X_train_cv, X_val_cv = X_train[train_index], X_train[val_index]
    y_train_cv, y_val_cv = y_train[train_index], y_train[val_index]

    # one-hot encoding
    vectorizer = CountVectorizer(lowercase=True)
    X_train_cv_ohe = vectorizer.fit_transform(X_train_cv)
    X_val_cv_ohe = vectorizer.transform(X_val_cv)

    # training model
    log_reg = LogisticRegression(random_state=42, verbose=0, max_iter=1000)
    log_reg.fit(X_train_cv_ohe, y_train_cv)

    # eval model
    y_pred = log_reg.predict(X_val_cv_ohe)

    scores.append(roc_auc_score(y_val_cv, y_pred))

# %%
add_model_eval('logistic regression (one hot encoding)', scores)

# %%
view_models_eval()
# Out:
# <style type="text/css">
# </style>
# <table id="T_886a2_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >model</th>
#       <th class="col_heading level0 col1" >roc_auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_886a2_row0_col0" class="data row0 col0" >logistic regression (one hot encoding)</td>
#       <td id="T_886a2_row0_col1" class="data row0 col1" > 0.49</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# As we can view the logistic regression model that train on one-hot encoding text dataset, the roc auc score is 0.49 only. It is as good as guessing the stock market will increase or decrease.

# %% [markdown]
# # 11.1.2 Deep Neural Network

# %%
scores = []

tscv = TimeSeriesSplit(n_splits=2)

for train_index, val_index in tscv.split(X_train):
    X_train_cv, X_val_cv = X_train[train_index], X_train[val_index]
    y_train_cv, y_val_cv = y_train[train_index], y_train[val_index]

    # one-hot encoding
    vectorizer = CountVectorizer(lowercase=True)
    X_train_cv_ohe = vectorizer.fit_transform(X_train_cv)
    X_val_cv_ohe = vectorizer.transform(X_val_cv)

    # convert into tensor
    X_train_cv_ohe = tf.constant(X_train_cv_ohe.toarray())
    X_val_cv_ohe = tf.constant(X_val_cv_ohe.toarray())
    y_train_cv = tf.constant(y_train_cv)
    y_val_cv = tf.constant(y_val_cv)

    # activate reproducible result
    tf.random.set_seed(42)

    # construct model
    input_shape = X_train_cv_ohe.shape[1]

    model = Sequential()
    model.add(Input(shape=(input_shape), name='input_layer'))
    model.add(Dense(256, activation='relu', name='hidden_layer_2'))
    model.add(Dense(128, activation='relu', name='hidden_layer_3'))  
    model.add(Dense(1, activation='sigmoid', name='output_layer'))

    # compile model
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=[AUC()])

    # optimisation
    early_stopping_cb = EarlyStopping(patience=5, restore_best_weights=True)

    # training model
    history = model.fit(X_train_cv_ohe, y_train_cv, epochs=100, 
                        validation_data=(X_val_cv_ohe, y_val_cv),
                        callbacks=[early_stopping_cb])
    

    # eval model
    y_pred = model.predict(X_val_cv_ohe)

    scores.append(roc_auc_score(y_val_cv, y_pred))
# Out:
# Train on 424 samples, validate on 424 samples
# Epoch 1/100
# 424/424 [==============================] - 2s 6ms/sample - loss: 0.7218 - auc_35: 0.4944 - val_loss: 0.7295 - val_auc_35: 0.5086
# Epoch 2/100
# 424/424 [==============================] - 1s 1ms/sample - loss: 0.3102 - auc_35: 0.9974 - val_loss: 0.7968 - val_auc_35: 0.5174
# Epoch 3/100
# 424/424 [==============================] - 1s 1ms/sample - loss: 0.0361 - auc_35: 1.0000 - val_loss: 1.0508 - val_auc_35: 0.5113
# Epoch 4/100
# 424/424 [==============================] - 1s 1ms/sample - loss: 0.0028 - auc_35: 1.0000 - val_loss: 1.5786 - val_auc_35: 0.5093
# Epoch 5/100
# 424/424 [==============================] - 1s 2ms/sample - loss: 3.9202e-04 - auc_35: 1.0000 - val_loss: 1.4299 - val_auc_35: 0.5067
# Epoch 6/100
# 424/424 [==============================] - 1s 2ms/sample - loss: 1.4673e-04 - auc_35: 1.0000 - val_loss: 1.3219 - val_auc_35: 0.5082
# Train on 848 samples, validate on 424 samples
# Epoch 1/100
# 848/848 [==============================] - 3s 3ms/sample - loss: 0.7216 - auc_36: 0.5190 - val_loss: 0.7374 - val_auc_36: 0.4498
# Epoch 2/100
# 848/848 [==============================] - 1s 2ms/sample - loss: 0.2724 - auc_36: 0.9955 - val_loss: 1.0458 - val_auc_36: 0.4654
# Epoch 3/100
# 848/848 [==============================] - 2s 2ms/sample - loss: 0.0160 - auc_36: 1.0000 - val_loss: 1.2060 - val_auc_36: 0.4728
# Epoch 4/100
# 848/848 [==============================] - 2s 2ms/sample - loss: 0.0019 - auc_36: 1.0000 - val_loss: 1.3175 - val_auc_36: 0.4760
# Epoch 5/100
# 848/848 [==============================] - 2s 2ms/sample - loss: 5.9151e-04 - auc_36: 1.0000 - val_loss: 1.3403 - val_auc_36: 0.4735
# Epoch 6/100
# 848/848 [==============================] - 2s 2ms/sample - loss: 3.4646e-04 - auc_36: 1.0000 - val_loss: 1.3603 - val_auc_36: 0.4725

# %%
add_model_eval('dnn (one hot encoding)', scores)

# %%
view_models_eval()
# Out:
# <style type="text/css">
# </style>
# <table id="T_cdedb_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >model</th>
#       <th class="col_heading level0 col1" >roc_auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cdedb_row0_col0" class="data row0 col0" >logistic regression (one hot encoding)</td>
#       <td id="T_cdedb_row0_col1" class="data row0 col1" > 0.49</td>
#     </tr>
#     <tr>
#       <td id="T_cdedb_row1_col0" class="data row1 col0" >dnn (one hot encoding)</td>
#       <td id="T_cdedb_row1_col1" class="data row1 col1" > 0.48</td>
#     </tr>
#   </tbody>
# </table>
